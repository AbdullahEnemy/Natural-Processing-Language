# %%
#Library calls
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import os
os.environ["TF_USE_LEGACY_KERAS"] = "1"
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Bidirectional
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import TrainingArguments, Trainer
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
from gensim.models import Word2Vec
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from nltk.translate.bleu_score import sentence_bleu

# %% [markdown]
# Question no 1

# %%
def preprocess_text(text):
    text = re.sub(r'[^\w\s]', '', text)  # eliminate punctuation
    text = re.sub(r'\bpladge\b', '', text, flags=re.IGNORECASE)  # remove the word "pladge"
    return text.strip()

# %%
data = pd.read_csv("/content/Input.tsv", sep="\t", names=["text", "label"])#data loading

data['text'] = data['text'].apply(preprocess_text)#preprocessing on text column
data = data[data['label'].isin(['P', 'N'])]# row Filtering with labels not in the desired set
encoder = LabelEncoder()#labels to numerical format: P -> 1, N -> 0
data['label'] = encoder.fit_transform(data['label'])
# Spliting the dataset
X_train, X_test, y_train, y_test = train_test_split(
    data['text'], data['label'], test_size=0.25, random_state=42
)
print(data.head())
# Out:
#                                                 text  label
# 1  میں نے ایٹم بم بنایا ھے او بھائی ایٹم بمب کوٹ ...      1
# 2  چندے سے انقلاب اور عمران خان وزیر اعظم نہیں بن...      0
# 4  سرچ انجن گوگل کے نائب صدر نے فضا میں  130000 ف...      1
# 5      ابھی تک اسکی لہریں کبھی کبھی آ جاتی ہیں یار أ      1
# 6  گندی زبان اور گٹر جیسے دماغ والے جاهل جیالے هو...      0

# %%
def assess_binary_model(model, X_data, true_labels):
    predicted_probs = model.predict(X_data)
    predicted_classes = (predicted_probs > 0.5).astype("int32")
    return {
        "Accuracy": accuracy_score(true_labels, predicted_classes),
        "Precision": precision_score(true_labels, predicted_classes),
        "Recall": recall_score(true_labels, predicted_classes),
        "F1-Score": f1_score(true_labels, predicted_classes)
    }

# Evaluation BERT
def assess_transformer_model(model, test_data_loader, true_labels):
    output_logits = model.predict(test_data_loader).logits
    predicted_classes = np.argmax(output_logits, axis=1)

    return {
        "Accuracy": accuracy_score(true_labels, predicted_classes),
        "Precision": precision_score(true_labels, predicted_classes),
        "Recall": recall_score(true_labels, predicted_classes),
        "F1-Score": f1_score(true_labels, predicted_classes)
    }

# %% [markdown]
# # Text tokenizer and padding

# %%
text_tokenizer = Tokenizer(oov_token="<OOV>")#out-of-vocabulary words
text_tokenizer.fit_on_texts(X_train)
vocab_size = len(text_tokenizer.word_index) + 1
train_sequences = text_tokenizer.texts_to_sequences(X_train)
test_sequences = text_tokenizer.texts_to_sequences(X_test)
max_sequence_length = 50
X_train_padded = pad_sequences(train_sequences, maxlen=max_sequence_length, padding='post')
X_test_padded = pad_sequences(test_sequences, maxlen=max_sequence_length, padding='post')

evaluation_results = {}

# %% [markdown]
# ALL models

# %%
# Build a simple RNN model for binary classification
rnn_model = Sequential([
    Embedding(vocab_size, 128),
    SimpleRNN(64, return_sequences=False),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

rnn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Train the model for 25 epochs with a batch size of 32 and 10% validation data
rnn_model.fit(X_train_padded, y_train, epochs=25, batch_size=32, validation_split=0.1)
evaluation_metrics = assess_binary_model(rnn_model, X_test_padded, y_test)#evaltating model on test data
evaluation_results["RNN"] = evaluation_metrics
print(evaluation_results["RNN"])
# Out:
# Epoch 1/25
# 21/21 [==============================] - 2s 25ms/step - loss: 0.7046 - accuracy: 0.4924 - val_loss: 0.7073 - val_accuracy: 0.4324
# Epoch 2/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.5156 - accuracy: 0.7924 - val_loss: 0.8087 - val_accuracy: 0.5135
# Epoch 3/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.2179 - accuracy: 0.9545 - val_loss: 0.9785 - val_accuracy: 0.5270
# Epoch 4/25
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0720 - accuracy: 0.9909 - val_loss: 1.1534 - val_accuracy: 0.5541
# Epoch 5/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0337 - accuracy: 0.9970 - val_loss: 1.1801 - val_accuracy: 0.5676
# Epoch 6/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0188 - accuracy: 0.9970 - val_loss: 1.2122 - val_accuracy: 0.5946
# Epoch 7/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0127 - accuracy: 0.9985 - val_loss: 1.2049 - val_accuracy: 0.5946
# Epoch 8/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0119 - accuracy: 0.9970 - val_loss: 1.1441 - val_accuracy: 0.6081
# Epoch 9/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 1.4404 - val_accuracy: 0.5270
# Epoch 10/25
# 21/21 [==============================] - 0s 13ms/step - loss: 0.0078 - accuracy: 0.9985 - val_loss: 1.2121 - val_accuracy: 0.5811
# Epoch 11/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0074 - accuracy: 0.9985 - val_loss: 1.4186 - val_accuracy: 0.5000
# Epoch 12/25
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0124 - accuracy: 0.9970 - val_loss: 1.3646 - val_accuracy: 0.5541
# Epoch 13/25
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 1.6069 - val_accuracy: 0.5405
# Epoch 14/25
# 21/21 [==============================] - 0s 23ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 1.5440 - val_accuracy: 0.5270
# Epoch 15/25
# 21/21 [==============================] - 0s 22ms/step - loss: 0.0203 - accuracy: 0.9955 - val_loss: 1.7194 - val_accuracy: 0.5000
# Epoch 16/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0123 - accuracy: 0.9985 - val_loss: 1.7146 - val_accuracy: 0.4730
# Epoch 17/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0118 - accuracy: 0.9970 - val_loss: 1.4089 - val_accuracy: 0.5135
# Epoch 18/25
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0152 - accuracy: 0.9955 - val_loss: 1.7965 - val_accuracy: 0.4595
# Epoch 19/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0083 - accuracy: 0.9970 - val_loss: 1.6004 - val_accuracy: 0.5541
# Epoch 20/25
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0086 - accuracy: 0.9985 - val_loss: 1.7527 - val_accuracy: 0.5270
# Epoch 21/25
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 1.6945 - val_accuracy: 0.4865
# Epoch 22/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 1.6264 - val_accuracy: 0.5135
# Epoch 23/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0098 - accuracy: 0.9970 - val_loss: 1.5894 - val_accuracy: 0.5270
# Epoch 24/25
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 1.4923 - val_accuracy: 0.5541
# Epoch 25/25
# 21/21 [==============================] - 0s 15ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 1.4519 - val_accuracy: 0.5541
# 8/8 [==============================] - 0s 3ms/step
# {'Accuracy': 0.5959183673469388, 'Precision': 0.5540540540540541, 'Recall': 0.7130434782608696, 'F1-Score': 0.623574144486692}

# %%
# Build the LSTM-based model for binary classification
lstm_model = Sequential([
    Embedding(vocab_size, 128),
    LSTM(64),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
lstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
lstm_model.fit(X_train_padded, y_train, epochs=25, batch_size=32, validation_split=0.1)
lstm_metrics = assess_binary_model(lstm_model, X_test_padded, y_test)
evaluation_results["LSTM"] = lstm_metrics

print(evaluation_results["LSTM"])
# Out:
# Epoch 1/25
# 21/21 [==============================] - 4s 67ms/step - loss: 0.6960 - accuracy: 0.4667 - val_loss: 0.6962 - val_accuracy: 0.4459
# Epoch 2/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.6941 - accuracy: 0.5076 - val_loss: 0.6944 - val_accuracy: 0.4459
# Epoch 3/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.6949 - accuracy: 0.4955 - val_loss: 0.6923 - val_accuracy: 0.5541
# Epoch 4/25
# 21/21 [==============================] - 1s 31ms/step - loss: 0.6956 - accuracy: 0.4848 - val_loss: 0.6930 - val_accuracy: 0.5541
# Epoch 5/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6970 - accuracy: 0.4909 - val_loss: 0.6957 - val_accuracy: 0.4459
# Epoch 6/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6941 - accuracy: 0.4970 - val_loss: 0.6932 - val_accuracy: 0.4459
# Epoch 7/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.6929 - accuracy: 0.5106 - val_loss: 0.6921 - val_accuracy: 0.5541
# Epoch 8/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6953 - accuracy: 0.4894 - val_loss: 0.6916 - val_accuracy: 0.5541
# Epoch 9/25
# 21/21 [==============================] - 1s 45ms/step - loss: 0.6940 - accuracy: 0.4697 - val_loss: 0.6934 - val_accuracy: 0.4459
# Epoch 10/25
# 21/21 [==============================] - 1s 39ms/step - loss: 0.6944 - accuracy: 0.5000 - val_loss: 0.6958 - val_accuracy: 0.4459
# Epoch 11/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6795 - accuracy: 0.5530 - val_loss: 0.7136 - val_accuracy: 0.5405
# Epoch 12/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.5029 - accuracy: 0.7985 - val_loss: 0.7676 - val_accuracy: 0.5000
# Epoch 13/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.4693 - accuracy: 0.8182 - val_loss: 1.0789 - val_accuracy: 0.5811
# Epoch 14/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.3855 - accuracy: 0.8803 - val_loss: 1.0200 - val_accuracy: 0.5135
# Epoch 15/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.4122 - accuracy: 0.8470 - val_loss: 1.0515 - val_accuracy: 0.4730
# Epoch 16/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.3507 - accuracy: 0.8924 - val_loss: 1.1082 - val_accuracy: 0.5000
# Epoch 17/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.3108 - accuracy: 0.9091 - val_loss: 1.2392 - val_accuracy: 0.5000
# Epoch 18/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.3144 - accuracy: 0.9091 - val_loss: 1.2324 - val_accuracy: 0.5000
# Epoch 19/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.2803 - accuracy: 0.9197 - val_loss: 1.2629 - val_accuracy: 0.5000
# Epoch 20/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.2633 - accuracy: 0.9258 - val_loss: 1.3148 - val_accuracy: 0.5000
# Epoch 21/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2480 - accuracy: 0.9318 - val_loss: 1.3433 - val_accuracy: 0.5000
# Epoch 22/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2452 - accuracy: 0.9333 - val_loss: 1.3449 - val_accuracy: 0.5000
# Epoch 23/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.2417 - accuracy: 0.9364 - val_loss: 1.3697 - val_accuracy: 0.5000
# Epoch 24/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.2261 - accuracy: 0.9424 - val_loss: 1.4107 - val_accuracy: 0.5000
# Epoch 25/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.2055 - accuracy: 0.9455 - val_loss: 1.4582 - val_accuracy: 0.5000
# 8/8 [==============================] - 0s 6ms/step
# {'Accuracy': 0.6163265306122448, 'Precision': 0.5668789808917197, 'Recall': 0.7739130434782608, 'F1-Score': 0.6544117647058824}

# %%
# Build the GRU-based model for binary classification
gru_model = Sequential([
    Embedding(vocab_size, 128),
    GRU(64),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
gru_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
gru_model.fit(X_train_padded, y_train, epochs=25, batch_size=32, validation_split=0.1)
gru_metrics = assess_binary_model(gru_model, X_test_padded, y_test)
evaluation_results["GRU"] = gru_metrics
print(evaluation_results["GRU"])
# Out:
# Epoch 1/25
# 21/21 [==============================] - 3s 47ms/step - loss: 0.6987 - accuracy: 0.4803 - val_loss: 0.6968 - val_accuracy: 0.4459
# Epoch 2/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6943 - accuracy: 0.5045 - val_loss: 0.6984 - val_accuracy: 0.4459
# Epoch 3/25
# 21/21 [==============================] - 1s 41ms/step - loss: 0.6938 - accuracy: 0.5121 - val_loss: 0.6935 - val_accuracy: 0.4459
# Epoch 4/25
# 21/21 [==============================] - 1s 35ms/step - loss: 0.6949 - accuracy: 0.4561 - val_loss: 0.6927 - val_accuracy: 0.5541
# Epoch 5/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6956 - accuracy: 0.4712 - val_loss: 0.6948 - val_accuracy: 0.4459
# Epoch 6/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6943 - accuracy: 0.4879 - val_loss: 0.6952 - val_accuracy: 0.4459
# Epoch 7/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6935 - accuracy: 0.4909 - val_loss: 0.6919 - val_accuracy: 0.5541
# Epoch 8/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6942 - accuracy: 0.4712 - val_loss: 0.6910 - val_accuracy: 0.5541
# Epoch 9/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6942 - accuracy: 0.4939 - val_loss: 0.6957 - val_accuracy: 0.4459
# Epoch 10/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6940 - accuracy: 0.4955 - val_loss: 0.6949 - val_accuracy: 0.4459
# Epoch 11/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.6941 - accuracy: 0.5182 - val_loss: 0.6945 - val_accuracy: 0.4459
# Epoch 12/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6949 - accuracy: 0.5000 - val_loss: 0.6932 - val_accuracy: 0.4459
# Epoch 13/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.6959 - accuracy: 0.4652 - val_loss: 0.6941 - val_accuracy: 0.4459
# Epoch 14/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6928 - accuracy: 0.5061 - val_loss: 0.6931 - val_accuracy: 0.5541
# Epoch 15/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.6954 - accuracy: 0.4939 - val_loss: 0.6954 - val_accuracy: 0.4459
# Epoch 16/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6963 - accuracy: 0.4636 - val_loss: 0.6911 - val_accuracy: 0.5541
# Epoch 17/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.6943 - accuracy: 0.4879 - val_loss: 0.6959 - val_accuracy: 0.4459
# Epoch 18/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6940 - accuracy: 0.4985 - val_loss: 0.6929 - val_accuracy: 0.5541
# Epoch 19/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6937 - accuracy: 0.4894 - val_loss: 0.6940 - val_accuracy: 0.4459
# Epoch 20/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.6942 - accuracy: 0.5030 - val_loss: 0.6946 - val_accuracy: 0.4459
# Epoch 21/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.6938 - accuracy: 0.5091 - val_loss: 0.6952 - val_accuracy: 0.4459
# Epoch 22/25
# 21/21 [==============================] - 1s 35ms/step - loss: 0.6941 - accuracy: 0.4909 - val_loss: 0.6932 - val_accuracy: 0.4459
# Epoch 23/25
# 21/21 [==============================] - 1s 40ms/step - loss: 0.6948 - accuracy: 0.5030 - val_loss: 0.6928 - val_accuracy: 0.5541
# Epoch 24/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6942 - accuracy: 0.4955 - val_loss: 0.6949 - val_accuracy: 0.4459
# Epoch 25/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.6923 - accuracy: 0.5136 - val_loss: 0.6941 - val_accuracy: 0.4459
# 8/8 [==============================] - 0s 6ms/step
# {'Accuracy': 0.46938775510204084, 'Precision': 0.46938775510204084, 'Recall': 1.0, 'F1-Score': 0.6388888888888888}

# %%
# Build the BiLSTM-based model for binary classification
bilstm_model = Sequential([
    Embedding(vocab_size, 128),
    Bidirectional(LSTM(64)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
bilstm_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
bilstm_model.fit(X_train_padded, y_train, epochs=25, batch_size=32, validation_split=0.1)
bilstm_metrics = assess_binary_model(bilstm_model, X_test_padded, y_test)
evaluation_results["BILSTM"] = bilstm_metrics
print(evaluation_results["BILSTM"])
# Out:
# Epoch 1/25
# 21/21 [==============================] - 6s 78ms/step - loss: 0.6948 - accuracy: 0.5258 - val_loss: 0.6915 - val_accuracy: 0.5676
# Epoch 2/25
# 21/21 [==============================] - 1s 44ms/step - loss: 0.6698 - accuracy: 0.6848 - val_loss: 0.7252 - val_accuracy: 0.3649
# Epoch 3/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.5597 - accuracy: 0.7591 - val_loss: 0.7344 - val_accuracy: 0.4595
# Epoch 4/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.2869 - accuracy: 0.9424 - val_loss: 0.7634 - val_accuracy: 0.4595
# Epoch 5/25
# 21/21 [==============================] - 1s 55ms/step - loss: 0.1480 - accuracy: 0.9742 - val_loss: 0.8984 - val_accuracy: 0.5270
# Epoch 6/25
# 21/21 [==============================] - 1s 60ms/step - loss: 0.0758 - accuracy: 0.9879 - val_loss: 1.1757 - val_accuracy: 0.4865
# Epoch 7/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0350 - accuracy: 0.9924 - val_loss: 1.3779 - val_accuracy: 0.4459
# Epoch 8/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0256 - accuracy: 0.9955 - val_loss: 1.3961 - val_accuracy: 0.5000
# Epoch 9/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0227 - accuracy: 0.9955 - val_loss: 1.5649 - val_accuracy: 0.4189
# Epoch 10/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0168 - accuracy: 0.9955 - val_loss: 1.6948 - val_accuracy: 0.4595
# Epoch 11/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0190 - accuracy: 0.9970 - val_loss: 1.5438 - val_accuracy: 0.4865
# Epoch 12/25
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0141 - accuracy: 0.9985 - val_loss: 1.7314 - val_accuracy: 0.4595
# Epoch 13/25
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 1.8936 - val_accuracy: 0.5270
# Epoch 14/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0163 - accuracy: 0.9939 - val_loss: 1.7237 - val_accuracy: 0.4324
# Epoch 15/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0102 - accuracy: 0.9955 - val_loss: 1.8234 - val_accuracy: 0.4189
# Epoch 16/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 1.9714 - val_accuracy: 0.4189
# Epoch 17/25
# 21/21 [==============================] - 1s 57ms/step - loss: 0.0090 - accuracy: 0.9985 - val_loss: 1.9383 - val_accuracy: 0.4324
# Epoch 18/25
# 21/21 [==============================] - 1s 59ms/step - loss: 0.0111 - accuracy: 0.9955 - val_loss: 1.9472 - val_accuracy: 0.4324
# Epoch 19/25
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 2.2278 - val_accuracy: 0.4459
# Epoch 20/25
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0064 - accuracy: 0.9970 - val_loss: 2.1699 - val_accuracy: 0.4189
# Epoch 21/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0053 - accuracy: 0.9985 - val_loss: 2.2462 - val_accuracy: 0.4189
# Epoch 22/25
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0047 - accuracy: 0.9970 - val_loss: 2.4992 - val_accuracy: 0.4054
# Epoch 23/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0040 - accuracy: 0.9985 - val_loss: 2.4941 - val_accuracy: 0.4324
# Epoch 24/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0042 - accuracy: 0.9970 - val_loss: 2.4921 - val_accuracy: 0.4189
# Epoch 25/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 2.5968 - val_accuracy: 0.4054
# 8/8 [==============================] - 1s 10ms/step
# {'Accuracy': 0.6244897959183674, 'Precision': 0.5851851851851851, 'Recall': 0.6869565217391305, 'F1-Score': 0.632}

# %%
# Initialize the multilingual BERT model and tokenizer
bert_model_name = "bert-base-multilingual-cased"
tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
multilingual_model = TFAutoModelForSequenceClassification.from_pretrained(bert_model_name, num_labels=2)
train_encodings = tokenizer(list(X_train), truncation=True, padding=True, max_length=128)
test_encodings = tokenizer(list(X_test), truncation=True, padding=True, max_length=128)
optimizer = Adam(learning_rate=2e-5)
train_dataset = tf.data.Dataset.from_tensor_slices((dict(train_encodings), y_train)).batch(16)# Convert data into TensorFlow datasets
test_dataset = tf.data.Dataset.from_tensor_slices((dict(test_encodings), y_test)).batch(16)
multilingual_model.compile(optimizer=optimizer,
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                           metrics=['accuracy'])
multilingual_model.fit(train_dataset, epochs=5, validation_data=test_dataset)
mbert_metrics = assess_transformer_model(multilingual_model, test_dataset, y_test)
evaluation_results["mBERT"] = mbert_metrics
print(evaluation_results["mBERT"])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFBertForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/5
# 46/46 [==============================] - 461s 9s/step - loss: 0.6974 - accuracy: 0.5177 - val_loss: 0.6871 - val_accuracy: 0.6327
# Epoch 2/5
# 46/46 [==============================] - 450s 10s/step - loss: 0.6768 - accuracy: 0.5981 - val_loss: 0.6504 - val_accuracy: 0.6245
# Epoch 3/5
# 46/46 [==============================] - 435s 9s/step - loss: 0.6321 - accuracy: 0.6512 - val_loss: 0.7060 - val_accuracy: 0.4776
# Epoch 4/5
# 46/46 [==============================] - 431s 9s/step - loss: 0.6426 - accuracy: 0.6131 - val_loss: 0.6072 - val_accuracy: 0.6735
# Epoch 5/5
# 46/46 [==============================] - 436s 9s/step - loss: 0.6079 - accuracy: 0.6744 - val_loss: 0.6249 - val_accuracy: 0.6490
# 16/16 [==============================] - 38s 2s/step
# {'Accuracy': 0.6489795918367347, 'Precision': 0.8372093023255814, 'Recall': 0.3130434782608696, 'F1-Score': 0.45569620253164556}

# %%
# Initialize XLM-RoBERTa model and tokenizer
xlm_model_name = "xlm-roberta-base"
tokenizer = AutoTokenizer.from_pretrained(xlm_model_name)
xlm_model = TFAutoModelForSequenceClassification.from_pretrained(xlm_model_name, num_labels=2)
train_encodings = tokenizer(list(X_train), truncation=True, padding=True, max_length=128)
test_encodings = tokenizer(list(X_test), truncation=True, padding=True, max_length=128)
train_dataset = tf.data.Dataset.from_tensor_slices((dict(train_encodings), y_train)).batch(16)
test_dataset = tf.data.Dataset.from_tensor_slices((dict(test_encodings), y_test)).batch(16)
xlm_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
xlm_model.fit(train_dataset, epochs=3, validation_data=test_dataset)
xlm_metrics = assess_transformer_model(xlm_model, test_dataset, y_test)
evaluation_results["XLMBERT"] = xlm_metrics
print(evaluation_results["XLMBERT"])
# Out:
# All PyTorch model weights were used when initializing TFXLMRobertaForSequenceClassification.
#
# Some weights or buffers of the TF 2.0 model TFXLMRobertaForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/3
# 46/46 [==============================] - 440s 9s/step - loss: 0.6965 - accuracy: 0.5054 - val_loss: 0.6898 - val_accuracy: 0.5306
# Epoch 2/3
# 46/46 [==============================] - 419s 9s/step - loss: 0.6928 - accuracy: 0.5014 - val_loss: 0.6811 - val_accuracy: 0.5837
# Epoch 3/3
# 46/46 [==============================] - 439s 10s/step - loss: 0.6852 - accuracy: 0.5640 - val_loss: 0.6904 - val_accuracy: 0.5388
# 16/16 [==============================] - 36s 2s/step
# {'Accuracy': 0.5387755102040817, 'Precision': 0.6666666666666666, 'Recall': 0.034782608695652174, 'F1-Score': 0.06611570247933884}

# %%
df_results = pd.DataFrame(evaluation_results[1:], columns=evaluation_results[0])
print(df_results)
# Out:
#      Model  Accuracy  Precision  Recall  F1-Score
# 0  XLMBERT    0.5388     0.6667  0.0348    0.0661
# 1    mBERT    0.6490     0.8372  0.3130    0.4557
# 2   BILSTM    0.6245     0.5852  0.6870    0.6320
# 3      GRU    0.4694     0.4694  1.0000    0.6389
# 4     LSTM    0.6163     0.5669  0.7739    0.6544
# 5      RNN    0.5469     0.5156  0.5739    0.5432

# %%
# Urdu text normalization for embedding preparation
def preprocess_text(text):
    # Eliminate digits
    text = re.sub(r"\d+", " ", text)
    # Strip out common English punctuation marks
    text = re.sub(r"""[!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~]+""", " ", text)
    # Remove Urdu-specific punctuation symbols
    text = re.sub(r"[:؛؟’‘٭ء،۔]+", " ", text)
    # Delete Arabic numerals
    text = re.sub(r"[٠‎١‎٢‎٣‎٤‎٥‎٦‎٧‎٨‎٩]+", " ", text)
    # Filter non-word characters (excluding spaces)
    text = re.sub(r"[^\w\s]", " ", text)
    # Strip English letters and digits
    text = re.sub(r"[a-zA-Z0-9]+", " ", text)
    # Normalize extra white spaces
    text = re.sub(r"\s+", " ", text)
    return text.strip()

# %% [markdown]
# Question no 2

# %%
def load_and_clean_data(filepath):
    processed_sentences = []
    data = pd.read_csv(filepath, sep='\t')

    for sentence in data['Tweet']:
        cleaned = preprocess_text(sentence)
        processed_sentences.append(cleaned.split())

    return processed_sentences
def train_w2v(sentences, filename):
    w2v_model = Word2Vec(
        sentences=sentences,
        vector_size=100,
        window=5,
        min_count=5,
        workers=4,
        sg=0  # CBOW model
    )
    w2v_model.save(filename)
    return w2v_model
def get_word_vector(model, word):
    if word in model.wv:
        print(f"Embedding for '{word}':\n{model.wv[word]}")
    else:
        print(f"'{word}' not found in the model vocabulary.")

# %%
sentences = load_and_clean_data("/content/Input.tsv")
w2v_model = train_w2v(sentences, "w2v_model")
get_word_vector(w2v_model, 'آپ')
# Out:
# Embedding for 'آپ':
# [-0.12803465  0.23627098  0.0536944   0.04548621  0.07707908 -0.31422073
#   0.09123978  0.3726027  -0.11469957 -0.09597608 -0.07373054 -0.22217876
#  -0.02202859  0.02562775  0.03884988 -0.10320386  0.10772666 -0.29465017
#  -0.07978034 -0.40121683  0.03057197  0.1258434   0.14919293 -0.11433229
#  -0.04719877  0.04385486 -0.15139683 -0.13392672 -0.17738768  0.12932323
#   0.22466369  0.03454817  0.0121672  -0.11035147 -0.17571992  0.2537493
#  -0.00504002 -0.14013863 -0.09821153 -0.34341547  0.1038917  -0.16273597
#  -0.0898766   0.00554703  0.20079497 -0.08291562 -0.09857216 -0.11621027
#   0.08492552  0.02501482  0.16610302 -0.13555522 -0.08198652 -0.02869631
#  -0.18323438  0.10242663  0.08131876  0.04286406 -0.21250407  0.05173036
#   0.04203551  0.05517119  0.02658407 -0.07634305 -0.18427299  0.15360023
#   0.17831989  0.16955064 -0.2443832   0.25011253 -0.12086792  0.03534761
#   0.06896741  0.01984213  0.19519942  0.12309249 -0.01295527  0.0180031
#  -0.13097537  0.09084111 -0.06110853 -0.03549282 -0.19770043  0.25456637
#  -0.07956612  0.04088837  0.08663191  0.28500256  0.25081924 -0.02577868
#   0.30414304  0.13511182 -0.06314579  0.04763435  0.29419148  0.20261751
#   0.1944857  -0.16314201  0.08077121 -0.03346808]

# %%
word2vec = Word2Vec.load("w2v_model")

embedding_dim = 100
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, index in text_tokenizer.word_index.items():
    if word in word2vec.wv:
        embedding_matrix[index] = word2vec.wv[word]
model_w2v = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix], trainable=True),
    LSTM(64),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

# %%
Q2_results={}
model_w2v.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_w2v.fit(X_train_padded, y_train, epochs=25, batch_size=32, validation_split=0.1)
metrics = assess_binary_model(model_w2v, X_test_padded, y_test)
Q2_results["W2V"] = metrics

print(Q2_results["W2V"])
# Out:
# Epoch 1/25
# 21/21 [==============================] - 5s 76ms/step - loss: 0.0158 - accuracy: 0.9970 - val_loss: 2.5924 - val_accuracy: 0.5270
# Epoch 2/25
# 21/21 [==============================] - 1s 35ms/step - loss: 0.0261 - accuracy: 0.9939 - val_loss: 2.0098 - val_accuracy: 0.4865
# Epoch 3/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0115 - accuracy: 0.9955 - val_loss: 1.8731 - val_accuracy: 0.4730
# Epoch 4/25
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0084 - accuracy: 0.9985 - val_loss: 2.2825 - val_accuracy: 0.4730
# Epoch 5/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0083 - accuracy: 0.9985 - val_loss: 2.3109 - val_accuracy: 0.5405
# Epoch 6/25
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0135 - accuracy: 0.9970 - val_loss: 2.1442 - val_accuracy: 0.4730
# Epoch 7/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 2.1509 - val_accuracy: 0.4595
# Epoch 8/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0050 - accuracy: 0.9955 - val_loss: 2.3472 - val_accuracy: 0.4730
# Epoch 9/25
# 21/21 [==============================] - 1s 38ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 2.2503 - val_accuracy: 0.4189
# Epoch 10/25
# 21/21 [==============================] - 1s 40ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 2.6162 - val_accuracy: 0.4324
# Epoch 11/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0030 - accuracy: 0.9985 - val_loss: 3.1608 - val_accuracy: 0.5135
# Epoch 12/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0032 - accuracy: 0.9985 - val_loss: 3.2548 - val_accuracy: 0.5270
# Epoch 13/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0031 - accuracy: 0.9985 - val_loss: 3.1728 - val_accuracy: 0.5135
# Epoch 14/25
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0042 - accuracy: 0.9970 - val_loss: 3.2298 - val_accuracy: 0.5135
# Epoch 15/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 3.1358 - val_accuracy: 0.4595
# Epoch 16/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0044 - accuracy: 0.9970 - val_loss: 3.3770 - val_accuracy: 0.5135
# Epoch 17/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 2.7957 - val_accuracy: 0.5000
# Epoch 18/25
# 21/21 [==============================] - 1s 24ms/step - loss: 0.0225 - accuracy: 0.9955 - val_loss: 2.9024 - val_accuracy: 0.4730
# Epoch 19/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0280 - accuracy: 0.9955 - val_loss: 2.1349 - val_accuracy: 0.5000
# Epoch 20/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0193 - accuracy: 0.9985 - val_loss: 2.2989 - val_accuracy: 0.5000
# Epoch 21/25
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0176 - accuracy: 0.9939 - val_loss: 2.1234 - val_accuracy: 0.5405
# Epoch 22/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.0312 - val_accuracy: 0.5000
# Epoch 23/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0061 - accuracy: 0.9955 - val_loss: 2.7135 - val_accuracy: 0.5135
# Epoch 24/25
# 21/21 [==============================] - 1s 26ms/step - loss: 0.0097 - accuracy: 0.9970 - val_loss: 2.2206 - val_accuracy: 0.5270
# Epoch 25/25
# 21/21 [==============================] - 1s 25ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 2.6770 - val_accuracy: 0.5000
# 8/8 [==============================] - 0s 6ms/step
# {'Accuracy': 0.5918367346938775, 'Precision': 0.5490196078431373, 'Recall': 0.7304347826086957, 'F1-Score': 0.6268656716417911}

# %%
# Function to read custom GloVe embeddings
def load_custom_glove_embeddings(file_path):
    embeddings = {}
    with open(file_path, 'r', encoding='utf8') as file:
        for line in file:
            split_line = line.strip().split()
            word = split_line[0]
            vector = np.array(split_line[1:], dtype='float32')
            embeddings[word] = vector
    return embeddings
# Load GloVe vectors for Urdu
urdu_glove = load_custom_glove_embeddings("/content/glove.6B.100d.txt")
# Prepare embedding matrix
embedding_dim = 100
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, idx in text_tokenizer.word_index.items():
    if word in urdu_glove:
        embedding_matrix[idx] = urdu_glove[word]
# Create LSTM model with GloVe embeddings
model_glove = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, weights=[embedding_matrix],
              input_length=max_sequence_length, trainable=True),
    LSTM(64),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model_glove.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_glove.fit(X_train_padded, y_train, epochs=25, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/25
# 21/21 [==============================] - 5s 88ms/step - loss: 0.6931 - accuracy: 0.5030 - val_loss: 0.6934 - val_accuracy: 0.4459
# Epoch 2/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6930 - accuracy: 0.5091 - val_loss: 0.6942 - val_accuracy: 0.4459
# Epoch 3/25
# 21/21 [==============================] - 1s 31ms/step - loss: 0.6937 - accuracy: 0.5288 - val_loss: 0.6925 - val_accuracy: 0.5541
# Epoch 4/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6928 - accuracy: 0.5015 - val_loss: 0.6956 - val_accuracy: 0.4459
# Epoch 5/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.6944 - accuracy: 0.4939 - val_loss: 0.6946 - val_accuracy: 0.4459
# Epoch 6/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6935 - accuracy: 0.5030 - val_loss: 0.6921 - val_accuracy: 0.5541
# Epoch 7/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6944 - accuracy: 0.4894 - val_loss: 0.6949 - val_accuracy: 0.4459
# Epoch 8/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6924 - accuracy: 0.5348 - val_loss: 0.6931 - val_accuracy: 0.5405
# Epoch 9/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6219 - accuracy: 0.6530 - val_loss: 1.0128 - val_accuracy: 0.5270
# Epoch 10/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.3808 - accuracy: 0.8818 - val_loss: 1.1374 - val_accuracy: 0.5541
# Epoch 11/25
# 21/21 [==============================] - 1s 31ms/step - loss: 0.1851 - accuracy: 0.9530 - val_loss: 0.8752 - val_accuracy: 0.5946
# Epoch 12/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.0890 - accuracy: 0.9848 - val_loss: 1.7502 - val_accuracy: 0.5270
# Epoch 13/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0571 - accuracy: 0.9909 - val_loss: 1.4006 - val_accuracy: 0.5946
# Epoch 14/25
# 21/21 [==============================] - 1s 32ms/step - loss: 0.0541 - accuracy: 0.9879 - val_loss: 1.8297 - val_accuracy: 0.4865
# Epoch 15/25
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0553 - accuracy: 0.9864 - val_loss: 2.4964 - val_accuracy: 0.4865
# Epoch 16/25
# 21/21 [==============================] - 1s 31ms/step - loss: 0.0398 - accuracy: 0.9939 - val_loss: 2.4490 - val_accuracy: 0.5135
# Epoch 17/25
# 21/21 [==============================] - 1s 36ms/step - loss: 0.0336 - accuracy: 0.9955 - val_loss: 2.1597 - val_accuracy: 0.5270
# Epoch 18/25
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0224 - accuracy: 0.9955 - val_loss: 2.0621 - val_accuracy: 0.5270
# Epoch 19/25
# 21/21 [==============================] - 1s 45ms/step - loss: 0.0217 - accuracy: 0.9970 - val_loss: 2.4486 - val_accuracy: 0.5405
# Epoch 20/25
# 21/21 [==============================] - 1s 28ms/step - loss: 0.0197 - accuracy: 0.9970 - val_loss: 2.5787 - val_accuracy: 0.5270
# Epoch 21/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0263 - accuracy: 0.9970 - val_loss: 2.5078 - val_accuracy: 0.5270
# Epoch 22/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0244 - accuracy: 0.9970 - val_loss: 2.5184 - val_accuracy: 0.5270
# Epoch 23/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0200 - accuracy: 0.9970 - val_loss: 2.4877 - val_accuracy: 0.5405
# Epoch 24/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0197 - accuracy: 0.9970 - val_loss: 2.4603 - val_accuracy: 0.5000
# Epoch 25/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.0239 - accuracy: 0.9955 - val_loss: 2.1797 - val_accuracy: 0.4865

# %%
# Evaluation
metrics = assess_binary_model(model_glove, X_test_padded, y_test)
Q2_results["Glove"] = metrics
print(Q2_results["Glove"])
# Out:
# 8/8 [==============================] - 1s 11ms/step
# {'Accuracy': 0.6244897959183674, 'Precision': 0.592, 'Recall': 0.6434782608695652, 'F1-Score': 0.6166666666666667}

# %%
import fasttext

# Function to clean and write Urdu text data to a file for FastText training
def prepare_fasttext_input(dataframe, filename):
    with open(filename, 'w', encoding='utf8') as file:
        for entry in dataframe['text']:
            cleaned_text = preprocess_text(entry)
            file.write(cleaned_text + '\n')
prepare_fasttext_input(data, 'urdu_fasttext.txt')
ft_model = fasttext.train_unsupervised('urdu_fasttext.txt', model='skipgram')
vector = ft_model.get_word_vector('آپ')
print(f"Embedding for the word 'آپ':\n{vector}")
# Out:
# Embedding for the word 'آپ':
# [ 0.08756117  0.27233404 -0.03027672  0.02105954  0.28861082  0.06018716
#  -0.10943206  0.09837036  0.26761922  0.2535413  -0.14851332  0.08834928
#  -0.19490933  0.2747523  -0.08996201 -0.01164204 -0.00234025  0.02624479
#   0.03076512  0.04537058 -0.04344109  0.10226315  0.10441438 -0.10251853
#   0.01428516 -0.03792332  0.10909264  0.02143142 -0.08700453  0.07883111
#  -0.00170354 -0.18016663 -0.2038048  -0.18591598 -0.18866086 -0.10308241
#  -0.060835   -0.03287821 -0.00256075 -0.04365546 -0.01296125  0.13208042
#   0.02172818  0.30531967  0.11016957 -0.18350549  0.04197414  0.07431116
#  -0.13104574  0.24267495 -0.26439863  0.03081083 -0.15196662  0.10380402
#  -0.02171432 -0.09979446  0.0901449   0.23734155  0.02337755  0.00050589
#   0.04686249  0.06690668  0.3902374   0.00760218  0.03881198 -0.07111625
#  -0.09715712  0.08002835 -0.10601524  0.08299984 -0.24419083  0.04942542
#  -0.09706189 -0.04694813 -0.05761055  0.07260178  0.15999132  0.12502673
#   0.10071829  0.04085848  0.19122687  0.23393068  0.18318418 -0.16917433
#   0.3042791   0.01495488  0.11686622  0.30054873  0.03980178 -0.11939587
#   0.31106767  0.0929613   0.29467803 -0.13136107 -0.2799535  -0.23776941
#  -0.06200032  0.0525022  -0.18694064 -0.06393696]

# %%
embedding_dim = 100
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, idx in text_tokenizer.word_index.items():
    embedding_matrix[idx] = ft_model.get_word_vector(word)

# Construct the LSTM model using FastText embeddings
model_fasttext = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim,
              weights=[embedding_matrix], input_length=max_sequence_length, trainable=True),
    LSTM(64),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model_fasttext.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model_fasttext.fit(X_train_padded, y_train, epochs=25, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/25
# 21/21 [==============================] - 3s 56ms/step - loss: 0.6940 - accuracy: 0.4818 - val_loss: 0.6940 - val_accuracy: 0.4459
# Epoch 2/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.6939 - accuracy: 0.4970 - val_loss: 0.6928 - val_accuracy: 0.5541
# Epoch 3/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.6936 - accuracy: 0.5167 - val_loss: 0.6949 - val_accuracy: 0.4459
# Epoch 4/25
# 21/21 [==============================] - 1s 38ms/step - loss: 0.6940 - accuracy: 0.4606 - val_loss: 0.6937 - val_accuracy: 0.4459
# Epoch 5/25
# 21/21 [==============================] - 1s 45ms/step - loss: 0.6930 - accuracy: 0.5045 - val_loss: 0.6938 - val_accuracy: 0.4324
# Epoch 6/25
# 21/21 [==============================] - 1s 44ms/step - loss: 0.6738 - accuracy: 0.5758 - val_loss: 0.7147 - val_accuracy: 0.4595
# Epoch 7/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.6240 - accuracy: 0.6348 - val_loss: 0.7153 - val_accuracy: 0.4595
# Epoch 8/25
# 21/21 [==============================] - 1s 30ms/step - loss: 0.3985 - accuracy: 0.8621 - val_loss: 1.1114 - val_accuracy: 0.6081
# Epoch 9/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.2523 - accuracy: 0.9303 - val_loss: 1.4162 - val_accuracy: 0.5270
# Epoch 10/25
# 21/21 [==============================] - 1s 35ms/step - loss: 0.1099 - accuracy: 0.9773 - val_loss: 1.2600 - val_accuracy: 0.5811
# Epoch 11/25
# 21/21 [==============================] - 1s 41ms/step - loss: 0.0749 - accuracy: 0.9864 - val_loss: 1.6541 - val_accuracy: 0.5811
# Epoch 12/25
# 21/21 [==============================] - 1s 44ms/step - loss: 0.0393 - accuracy: 0.9939 - val_loss: 1.8310 - val_accuracy: 0.5811
# Epoch 13/25
# 21/21 [==============================] - 1s 42ms/step - loss: 0.0272 - accuracy: 0.9955 - val_loss: 1.9763 - val_accuracy: 0.5676
# Epoch 14/25
# 21/21 [==============================] - 1s 43ms/step - loss: 0.0276 - accuracy: 0.9955 - val_loss: 2.0382 - val_accuracy: 0.5676
# Epoch 15/25
# 21/21 [==============================] - 1s 34ms/step - loss: 0.0207 - accuracy: 0.9970 - val_loss: 2.1125 - val_accuracy: 0.5135
# Epoch 16/25
# 21/21 [==============================] - 1s 29ms/step - loss: 0.0269 - accuracy: 0.9955 - val_loss: 1.8962 - val_accuracy: 0.5270
# Epoch 17/25
# 21/21 [==============================] - 1s 49ms/step - loss: 0.0210 - accuracy: 0.9970 - val_loss: 1.9776 - val_accuracy: 0.5541
# Epoch 18/25
# 21/21 [==============================] - 1s 46ms/step - loss: 0.0216 - accuracy: 0.9939 - val_loss: 1.9526 - val_accuracy: 0.5135
# Epoch 19/25
# 21/21 [==============================] - 1s 51ms/step - loss: 0.0214 - accuracy: 0.9970 - val_loss: 2.3840 - val_accuracy: 0.5000
# Epoch 20/25
# 21/21 [==============================] - 1s 65ms/step - loss: 0.0266 - accuracy: 0.9939 - val_loss: 2.5267 - val_accuracy: 0.5000
# Epoch 21/25
# 21/21 [==============================] - 1s 65ms/step - loss: 0.0167 - accuracy: 0.9970 - val_loss: 2.5073 - val_accuracy: 0.5270
# Epoch 22/25
# 21/21 [==============================] - 1s 50ms/step - loss: 0.0165 - accuracy: 0.9970 - val_loss: 2.6689 - val_accuracy: 0.4595
# Epoch 23/25
# 21/21 [==============================] - 1s 54ms/step - loss: 0.0144 - accuracy: 0.9970 - val_loss: 2.4904 - val_accuracy: 0.5270
# Epoch 24/25
# 21/21 [==============================] - 1s 60ms/step - loss: 0.0138 - accuracy: 0.9985 - val_loss: 2.5424 - val_accuracy: 0.5270
# Epoch 25/25
# 21/21 [==============================] - 1s 27ms/step - loss: 0.0088 - accuracy: 0.9985 - val_loss: 2.6795 - val_accuracy: 0.5270

# %%
metrics = assess_binary_model(model_fasttext, X_test_padded, y_test)
Q2_results["FastText"] = metrics

print(Q2_results["FastText"])
# Out:
# 8/8 [==============================] - 0s 7ms/step
# {'Accuracy': 0.6244897959183674, 'Precision': 0.5804195804195804, 'Recall': 0.7217391304347827, 'F1-Score': 0.6434108527131783}

# %%
data = pd.read_csv("/content/Input.tsv", sep="\t", names=["text", "label"])
data['text'] = data['text'].apply(lambda t: re.sub(r'[^\w\s]', '', t).strip())
data = data[data['label'].isin(['P', 'N'])]

encoder = LabelEncoder()
data['label'] = encoder.fit_transform(data['label'])  # 'P' → 1, 'N' → 0
elmo_model = Embedder('177')
tokenized_texts = data['text'].tolist()
elmo_vectors = elmo_model.sents2elmo(tokenized_texts)

X = np.array([np.mean(emb, axis=0) for emb in elmo_vectors])
y = np.array(data['label'], dtype=np.float32)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

X_train_lstm = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_lstm = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

model_elmo = Sequential([
    LSTM(64, input_shape=(1, X.shape[1])),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model_elmo.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model_elmo.fit(X_train_lstm, y_train, epochs=25, batch_size=32, validation_split=0.1)

def evaluate(model, X, y_true):
    y_prob = model.predict(X)
    y_pred = (y_prob > 0.5).astype(int)
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1-Score": f1_score(y_true, y_pred)
    }



Q2_results["ELMO"] = evaluate(model_elmo, X_test_lstm, y_test)
print(Q2_results["ELMO"])
# Out:
# {'Accuracy': 0.5183673469387755, 'Precision': 0.49032258064516127, 'Recall': 0.6608695652173913, 'F1-Score': 0.562962962962963}

# %%
df = pd.DataFrame(Q2_results).T
df = df.T
df = df.loc[['F1-Score', 'Accuracy', 'Precision', 'Recall']]
print(df)
# Out:
#                 W2V     Glove  FastText      ELMO
# F1-Score   0.626866  0.616667  0.643411  0.562963
# Accuracy   0.591837  0.624490  0.624490  0.518367
# Precision  0.549020  0.592000  0.580420  0.490323
# Recall     0.730435  0.643478  0.721739  0.660870

# %% [markdown]
# # Part 2
#
# # Q3

# %%
with open('/content/english.txt', 'r', encoding='utf-8') as f:
    english_sentences = f.readlines()

with open('/content/urdu.txt', 'r', encoding='utf-8') as f:
    urdu_sentences = f.readlines()

english_sentences = [line.strip() for line in english_sentences]
urdu_sentences = [line.strip() for line in urdu_sentences]

df = pd.DataFrame({
    'english': english_sentences,
    'urdu': urdu_sentences
})

df = df[['english', 'urdu']].dropna().reset_index(drop=True)

print(df.head())

df['urdu'] = df['urdu'].apply(lambda x: 'start ' + x + ' end')

eng_tokenizer = Tokenizer()
eng_tokenizer.fit_on_texts(df['english'])

urdu_tokenizer = Tokenizer()
urdu_tokenizer.fit_on_texts(df['urdu'])
input_sequences = eng_tokenizer.texts_to_sequences(df['english'])
target_sequences = urdu_tokenizer.texts_to_sequences(df['urdu'])

max_input_len = max(len(seq) for seq in input_sequences)
max_output_len = max(len(seq) for seq in target_sequences)

input_sequences = pad_sequences(input_sequences, maxlen=max_input_len, padding='post')
target_sequences = pad_sequences(target_sequences, maxlen=max_output_len, padding='post')
X_train, X_val, y_train, y_val = train_test_split(input_sequences, target_sequences, test_size=0.1)

input_vocab_size = len(eng_tokenizer.word_index) + 1
output_vocab_size = len(urdu_tokenizer.word_index) + 1
# Out:
#                 english                       urdu
# 0   is zain your nephew      زین تمہارا بھتیجا ہے۔
# 1  i wish youd trust me  کاش تم مجھ پر بھروسہ کرتے
# 2      did he touch you      کیا اس نے آپ کو چھوا؟
# 3      its part of life         اس کی زندگی کا حصہ
# 4        zain isnt ugly        زین بدصورت نہیں ہے۔

# %%
def evaluate_bleu(model, X_train, X_val, y_train, y_val, urdu_tokenizer, max_output_len):
    smooth = SmoothingFunction().method1
    scores = []

    # Combine first 90 from train and first 10 from val
    eval_inputs = np.concatenate([X_train[:90], X_val[:10]], axis=0)
    eval_targets = np.concatenate([y_train[:90], y_val[:10]], axis=0)

    for i in range(len(eval_inputs)):
        input_seq = eval_inputs[i:i+1]
        decoder_input = np.zeros((1, max_output_len - 1))
        decoder_input[0, 0] = urdu_tokenizer.word_index['start']

        for t in range(1, max_output_len):
            output_tokens = model.predict(input_seq, verbose=0)  # Make sure the input shape aligns with the model's input requirements
            sampled_token_index = np.argmax(output_tokens[0, t - 1, :])
            decoder_input[0, t] = sampled_token_index
            if sampled_token_index == urdu_tokenizer.word_index['end']:
                break

        predicted = decoder_input[0][1:t]
        reference = eval_targets[i][1:]  # Avoid 'start' token in the reference
        scores.append(sentence_bleu([reference], predicted, smoothing_function=smooth))

    return np.mean(scores)

# %%
def create_rnn_model():
    # Encoder
    encoder_input = Input(shape=(max_input_len,))
    enc_emb = Embedding(input_vocab_size, 256)(encoder_input)
    encoder_output, state_h = SimpleRNN(256, return_state=True)(enc_emb)

    # Decoder
    decoder_input = Input(shape=(max_output_len - 1,))
    dec_emb = Embedding(output_vocab_size, 256)(decoder_input)  # Shape: (batch_size, max_output_len-1, 256)
    decoder_output = SimpleRNN(256, return_sequences=True)(dec_emb, initial_state=state_h)
    output = Dense(output_vocab_size, activation='softmax')(decoder_output)  # Shape: (batch_size, max_output_len-1, output_vocab_size)

    model = Model([encoder_input, decoder_input], output)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

rnn_model = create_rnn_model()
rnn_model.fit([X_train, y_train[:, :-1]], y_train[:, 1:, np.newaxis], epochs=50, batch_size=64,
              validation_data=([X_val, y_val[:, :-1]], y_val[:, 1:, np.newaxis]))
# Out:
# Epoch 1/50
# 345/345 [==============================] - 18s 49ms/step - loss: 1.7704 - val_loss: 1.3629
# Epoch 2/50
# 345/345 [==============================] - 17s 50ms/step - loss: 1.2716 - val_loss: 1.2237
# Epoch 3/50
# 345/345 [==============================] - 17s 49ms/step - loss: 1.1367 - val_loss: 1.1519
# Epoch 4/50
# 345/345 [==============================] - 17s 49ms/step - loss: 1.0520 - val_loss: 1.1168
# Epoch 5/50
# 345/345 [==============================] - 17s 49ms/step - loss: 0.9912 - val_loss: 1.1016
# Epoch 6/50
# 345/345 [==============================] - 17s 49ms/step - loss: 0.9442 - val_loss: 1.0945
# Epoch 7/50
# 345/345 [==============================] - 17s 50ms/step - loss: 0.9045 - val_loss: 1.0878
# Epoch 8/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.8711 - val_loss: 1.0909
# Epoch 9/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.8409 - val_loss: 1.0906
# Epoch 10/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.8142 - val_loss: 1.0951
# Epoch 11/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.7908 - val_loss: 1.0964
# Epoch 12/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.7699 - val_loss: 1.1024
# Epoch 13/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.7507 - val_loss: 1.1074
# Epoch 14/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.7337 - val_loss: 1.1146
# Epoch 15/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.7183 - val_loss: 1.1202
# Epoch 16/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.7044 - val_loss: 1.1267
# Epoch 17/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6922 - val_loss: 1.1359
# Epoch 18/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.6802 - val_loss: 1.1417
# Epoch 19/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6698 - val_loss: 1.1491
# Epoch 20/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6601 - val_loss: 1.1559
# Epoch 21/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6511 - val_loss: 1.1646
# Epoch 22/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6428 - val_loss: 1.1697
# Epoch 23/50
# 345/345 [==============================] - 17s 51ms/step - loss: 0.6356 - val_loss: 1.1798
# Epoch 24/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6293 - val_loss: 1.1860
# Epoch 25/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6230 - val_loss: 1.1947
# Epoch 26/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6172 - val_loss: 1.2009
# Epoch 27/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.6121 - val_loss: 1.2069
# Epoch 28/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6076 - val_loss: 1.2160
# Epoch 29/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.6030 - val_loss: 1.2234
# Epoch 30/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.5995 - val_loss: 1.2295
# Epoch 31/50
# 345/345 [==============================] - 17s 51ms/step - loss: 0.5955 - val_loss: 1.2363
# Epoch 32/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.5925 - val_loss: 1.2419
# Epoch 33/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.5892 - val_loss: 1.2485
# Epoch 34/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.5865 - val_loss: 1.2573
# Epoch 35/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.5839 - val_loss: 1.2612
# Epoch 36/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.5817 - val_loss: 1.2649
# Epoch 37/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5790 - val_loss: 1.2721
# Epoch 38/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5778 - val_loss: 1.2783
# Epoch 39/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5758 - val_loss: 1.2818
# Epoch 40/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5737 - val_loss: 1.2861
# Epoch 41/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5724 - val_loss: 1.2946
# Epoch 42/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5707 - val_loss: 1.2997
# Epoch 43/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5695 - val_loss: 1.3037
# Epoch 44/50
# 345/345 [==============================] - 21s 62ms/step - loss: 0.5680 - val_loss: 1.3080
# Epoch 45/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5674 - val_loss: 1.3132
# Epoch 46/50
# 345/345 [==============================] - 21s 61ms/step - loss: 0.5663 - val_loss: 1.3145
# Epoch 47/50
# 345/345 [==============================] - 19s 56ms/step - loss: 0.5651 - val_loss: 1.3212
# Epoch 48/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5642 - val_loss: 1.3248
# Epoch 49/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.5632 - val_loss: 1.3279
# Epoch 50/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.5622 - val_loss: 1.3326
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step

# %%
trans_models = {}

# %%
trans_models['RNN_Model'] =evaluate_bleu(rnn_model)

print(trans_models['RNN_Model'])
# Out:
# 0.0017900319764852235

# %%
def create_birnn_model():
    encoder_input = Input(shape=(max_input_len,))
    enc_emb = Embedding(input_vocab_size, 256)(encoder_input)

    bi_rnn = Bidirectional(SimpleRNN(256, return_state=True), merge_mode=None)
    forward_output, backward_output, forward_h, backward_h = bi_rnn(enc_emb)

    state_h = tf.keras.layers.Concatenate()([forward_h, backward_h])

    decoder_input = Input(shape=(max_output_len-1,))
    dec_emb = Embedding(output_vocab_size, 512)(decoder_input)
    decoder_output = SimpleRNN(512, return_sequences=True)(dec_emb, initial_state=state_h)

    output = Dense(output_vocab_size, activation='softmax')(decoder_output)

    model = Model([encoder_input, decoder_input], output)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
    return model



birnn_model = create_birnn_model()
birnn_model.fit([X_train, y_train[:, :-1]], y_train[:, 1:, np.newaxis], epochs=50, batch_size=64, validation_data=([X_val, y_val[:, :-1]], y_val[:, 1:, np.newaxis]))
# Out:
# Epoch 1/50
# 345/345 [==============================] - 34s 95ms/step - loss: 1.5926 - val_loss: 1.2728
# Epoch 2/50
# 345/345 [==============================] - 33s 95ms/step - loss: 1.1773 - val_loss: 1.1348
# Epoch 3/50
# 345/345 [==============================] - 34s 97ms/step - loss: 1.0162 - val_loss: 1.0342
# Epoch 4/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.8980 - val_loss: 0.9980
# Epoch 5/50
# 345/345 [==============================] - 33s 97ms/step - loss: 0.8020 - val_loss: 0.9456
# Epoch 6/50
# 345/345 [==============================] - 32s 94ms/step - loss: 0.7184 - val_loss: 0.9088
# Epoch 7/50
# 345/345 [==============================] - 32s 91ms/step - loss: 0.6439 - val_loss: 0.8882
# Epoch 8/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.5760 - val_loss: 0.8785
# Epoch 9/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.5167 - val_loss: 0.8611
# Epoch 10/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.4584 - val_loss: 0.8634
# Epoch 11/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.4050 - val_loss: 0.8580
# Epoch 12/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.3566 - val_loss: 0.8500
# Epoch 13/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.3127 - val_loss: 0.8540
# Epoch 14/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.2793 - val_loss: 0.8635
# Epoch 15/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.2385 - val_loss: 0.8576
# Epoch 16/50
# 345/345 [==============================] - 32s 93ms/step - loss: 0.2067 - val_loss: 0.8687
# Epoch 17/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.1785 - val_loss: 0.8787
# Epoch 18/50
# 345/345 [==============================] - 32s 93ms/step - loss: 0.1533 - val_loss: 0.8888
# Epoch 19/50
# 345/345 [==============================] - 34s 97ms/step - loss: 0.1325 - val_loss: 0.9011
# Epoch 20/50
# 345/345 [==============================] - 34s 98ms/step - loss: 0.1178 - val_loss: 0.9113
# Epoch 21/50
# 345/345 [==============================] - 35s 101ms/step - loss: 0.1012 - val_loss: 0.9295
# Epoch 22/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.0905 - val_loss: 0.9455
# Epoch 23/50
# 345/345 [==============================] - 33s 97ms/step - loss: 0.0782 - val_loss: 0.9530
# Epoch 24/50
# 345/345 [==============================] - 33s 97ms/step - loss: 0.0718 - val_loss: 0.9716
# Epoch 25/50
# 345/345 [==============================] - 34s 97ms/step - loss: 0.0655 - val_loss: 0.9913
# Epoch 26/50
# 345/345 [==============================] - 34s 97ms/step - loss: 0.0605 - val_loss: 1.0081
# Epoch 27/50
# 345/345 [==============================] - 34s 97ms/step - loss: 0.0563 - val_loss: 1.0211
# Epoch 28/50
# 345/345 [==============================] - 33s 97ms/step - loss: 0.0514 - val_loss: 1.0409
# Epoch 29/50
# 345/345 [==============================] - 34s 97ms/step - loss: 0.0519 - val_loss: 1.0482
# Epoch 30/50
# 345/345 [==============================] - 34s 98ms/step - loss: 0.0501 - val_loss: 1.0768
# Epoch 31/50
# 345/345 [==============================] - 34s 97ms/step - loss: 0.0460 - val_loss: 1.0809
# Epoch 32/50
# 345/345 [==============================] - 34s 97ms/step - loss: 0.0410 - val_loss: 1.1021
# Epoch 33/50
# 345/345 [==============================] - 34s 99ms/step - loss: 0.0395 - val_loss: 1.1110
# Epoch 34/50
# 345/345 [==============================] - 34s 98ms/step - loss: 0.0423 - val_loss: 1.1314
# Epoch 35/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.0477 - val_loss: 1.1381
# Epoch 36/50
# 345/345 [==============================] - 33s 95ms/step - loss: 0.0423 - val_loss: 1.1453
# Epoch 37/50
# 345/345 [==============================] - 32s 92ms/step - loss: 0.0338 - val_loss: 1.1525
# Epoch 38/50
# 345/345 [==============================] - 33s 95ms/step - loss: 0.0290 - val_loss: 1.1546
# Epoch 39/50
# 345/345 [==============================] - 33s 97ms/step - loss: 0.0313 - val_loss: 1.1728
# Epoch 40/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.0380 - val_loss: 1.1861
# Epoch 41/50
# 345/345 [==============================] - 33s 97ms/step - loss: 0.0454 - val_loss: 1.2055
# Epoch 42/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.0462 - val_loss: 1.2028
# Epoch 43/50
# 345/345 [==============================] - 34s 98ms/step - loss: 0.0321 - val_loss: 1.2017
# Epoch 44/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.0243 - val_loss: 1.2081
# Epoch 45/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.0222 - val_loss: 1.2313
# Epoch 46/50
# 345/345 [==============================] - 33s 95ms/step - loss: 0.0292 - val_loss: 1.2403
# Epoch 47/50
# 345/345 [==============================] - 34s 98ms/step - loss: 0.0452 - val_loss: 1.2627
# Epoch 48/50
# 345/345 [==============================] - 33s 95ms/step - loss: 0.0452 - val_loss: 1.2591
# Epoch 49/50
# 345/345 [==============================] - 33s 97ms/step - loss: 0.0359 - val_loss: 1.2571
# Epoch 50/50
# 345/345 [==============================] - 33s 96ms/step - loss: 0.0292 - val_loss: 1.2762

# %%
trans_models['BIRNN_Model'] = evaluate_bleu(birnn_model)

print(trans_models['BIRNN_Model'])
# Out:
# 0.05376326907496855

# %%
def create_lstm_model():
    encoder_input = Input(shape=(max_input_len,))
    enc_emb = Embedding(input_vocab_size, 256)(encoder_input)
    encoder_output, state_h, state_c = LSTM(256, return_state=True)(enc_emb)

    decoder_input = Input(shape=(max_output_len-1,))
    dec_emb = Embedding(output_vocab_size, 256)(decoder_input)
    decoder_output = LSTM(256, return_sequences=True)(dec_emb, initial_state=[state_h, state_c])
    output = Dense(output_vocab_size, activation='softmax')(decoder_output)

    model = Model([encoder_input, decoder_input], output)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
    return model



lstm_model = create_lstm_model()
lstm_model.fit([X_train, y_train[:, :-1]], y_train[:, 1:, np.newaxis], epochs=50, batch_size=64, validation_data=([X_val, y_val[:, :-1]], y_val[:, 1:, np.newaxis]))
# Out:
# Epoch 1/50
# 345/345 [==============================] - 29s 79ms/step - loss: 1.7985 - val_loss: 1.4143
# Epoch 2/50
# 345/345 [==============================] - 27s 78ms/step - loss: 1.3453 - val_loss: 1.3034
# Epoch 3/50
# 345/345 [==============================] - 27s 78ms/step - loss: 1.2057 - val_loss: 1.1817
# Epoch 4/50
# 345/345 [==============================] - 27s 79ms/step - loss: 1.0786 - val_loss: 1.0760
# Epoch 5/50
# 345/345 [==============================] - 27s 78ms/step - loss: 0.9627 - val_loss: 0.9911
# Epoch 6/50
# 345/345 [==============================] - 27s 79ms/step - loss: 0.8594 - val_loss: 0.9175
# Epoch 7/50
# 345/345 [==============================] - 27s 78ms/step - loss: 0.7643 - val_loss: 0.8603
# Epoch 8/50
# 345/345 [==============================] - 27s 79ms/step - loss: 0.6787 - val_loss: 0.8118
# Epoch 9/50
# 345/345 [==============================] - 27s 79ms/step - loss: 0.6030 - val_loss: 0.7748
# Epoch 10/50
# 345/345 [==============================] - 27s 79ms/step - loss: 0.5332 - val_loss: 0.7400
# Epoch 11/50
# 345/345 [==============================] - 27s 79ms/step - loss: 0.4686 - val_loss: 0.7147
# Epoch 12/50
# 345/345 [==============================] - 28s 82ms/step - loss: 0.4090 - val_loss: 0.6920
# Epoch 13/50
# 345/345 [==============================] - 28s 81ms/step - loss: 0.3547 - val_loss: 0.6751
# Epoch 14/50
# 345/345 [==============================] - 28s 81ms/step - loss: 0.3061 - val_loss: 0.6632
# Epoch 15/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.2627 - val_loss: 0.6532
# Epoch 16/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.2250 - val_loss: 0.6447
# Epoch 17/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.1924 - val_loss: 0.6436
# Epoch 18/50
# 345/345 [==============================] - 27s 80ms/step - loss: 0.1642 - val_loss: 0.6423
# Epoch 19/50
# 345/345 [==============================] - 27s 80ms/step - loss: 0.1401 - val_loss: 0.6450
# Epoch 20/50
# 345/345 [==============================] - 27s 80ms/step - loss: 0.1188 - val_loss: 0.6506
# Epoch 21/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.1012 - val_loss: 0.6533
# Epoch 22/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0855 - val_loss: 0.6557
# Epoch 23/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0727 - val_loss: 0.6632
# Epoch 24/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0618 - val_loss: 0.6720
# Epoch 25/50
# 345/345 [==============================] - 28s 81ms/step - loss: 0.0523 - val_loss: 0.6853
# Epoch 26/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0448 - val_loss: 0.6903
# Epoch 27/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0377 - val_loss: 0.6962
# Epoch 28/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0323 - val_loss: 0.7077
# Epoch 29/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0279 - val_loss: 0.7154
# Epoch 30/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0243 - val_loss: 0.7222
# Epoch 31/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0215 - val_loss: 0.7356
# Epoch 32/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0194 - val_loss: 0.7409
# Epoch 33/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0168 - val_loss: 0.7468
# Epoch 34/50
# 345/345 [==============================] - 28s 81ms/step - loss: 0.0157 - val_loss: 0.7581
# Epoch 35/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0136 - val_loss: 0.7705
# Epoch 36/50
# 345/345 [==============================] - 28s 81ms/step - loss: 0.0126 - val_loss: 0.7718
# Epoch 37/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0114 - val_loss: 0.7844
# Epoch 38/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0112 - val_loss: 0.7865
# Epoch 39/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0130 - val_loss: 0.7965
# Epoch 40/50
# 345/345 [==============================] - 28s 81ms/step - loss: 0.0122 - val_loss: 0.8031
# Epoch 41/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0104 - val_loss: 0.8117
# Epoch 42/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0075 - val_loss: 0.8154
# Epoch 43/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0052 - val_loss: 0.8172
# Epoch 44/50
# 345/345 [==============================] - 28s 82ms/step - loss: 0.0043 - val_loss: 0.8194
# Epoch 45/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0042 - val_loss: 0.8282
# Epoch 46/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0070 - val_loss: 0.8537
# Epoch 47/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0244 - val_loss: 0.8419
# Epoch 48/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0148 - val_loss: 0.8455
# Epoch 49/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0065 - val_loss: 0.8364
# Epoch 50/50
# 345/345 [==============================] - 28s 80ms/step - loss: 0.0036 - val_loss: 0.8416

# %%
trans_models['LSTM_Model'] =evaluate_bleu(lstm_model)

print(trans_models['LSTM_Model'])
# Out:
# 0.05732336259749588

# %%
def evaluate_model_bleu(model, tokenizer_src, tokenizer_tgt, input_texts, target_texts, max_input_len, max_output_len):
    bleu_scores = []
    for src, tgt in zip(input_texts, target_texts):
        src_seq = tokenizer_src.texts_to_sequences([src])
        src_seq = tf.keras.preprocessing.sequence.pad_sequences(src_seq, maxlen=max_input_len, padding='post')
        tgt_input_seq = [tokenizer_tgt.word_index['start']]

        for _ in range(max_output_len):
            tgt_seq = tf.keras.preprocessing.sequence.pad_sequences([tgt_input_seq], maxlen=max_output_len-1, padding='post')
            predictions = model.predict([src_seq, tgt_seq], verbose=0)
            next_word_id = predictions[0, len(tgt_input_seq)-1].argmax()
            tgt_input_seq.append(next_word_id)
            if tokenizer_tgt.index_word[next_word_id] == 'end':
                break
        translated = [tokenizer_tgt.index_word.get(idx, '') for idx in tgt_input_seq if idx != 0]
        reference = tgt.split()
        bleu_scores.append(sentence_bleu([reference], translated))
    return sum(bleu_scores) / len(bleu_scores)

# %%
class PositionalEncodingLayer(tf.keras.layers.Layer):
    def __init__(self, max_len, d_model):
        super(PositionalEncodingLayer, self).__init__()
        position = np.arange(max_len)[:, np.newaxis]
        dimension = np.arange(d_model)[np.newaxis, :]
        rates = 1 / np.power(10000, (2 * (dimension // 2)) / np.float32(d_model))
        angles = position * rates

        # Applying sine to even indices and cosine to odd indices
        angles[:, 0::2] = np.sin(angles[:, 0::2])
        angles[:, 1::2] = np.cos(angles[:, 1::2])

        self.positional_encoding = tf.cast(angles[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        return x + self.positional_encoding[:, :tf.shape(x)[1], :]

class TransformerDecoderLayer(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerDecoderLayer, self).__init__()
        self.self_attention = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.encoder_attention = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.feed_forward = tf.keras.Sequential([
            Dense(ff_dim, activation='relu'),
            Dense(embed_dim)
        ])
        self.layer_norm1 = LayerNormalization(epsilon=1e-6)
        self.layer_norm2 = LayerNormalization(epsilon=1e-6)
        self.layer_norm3 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)
        self.dropout3 = Dropout(rate)

    def call(self, x, encoder_output, training):
        # Creating a mask to prevent attention to future tokens
        look_ahead_mask = tf.linalg.band_part(tf.ones((tf.shape(x)[1], tf.shape(x)[1])), -1, 0)

        self_attention_output = self.self_attention(x, x, attention_mask=look_ahead_mask)
        self_attention_output = self.dropout1(self_attention_output, training=training)
        norm1_output = self.layer_norm1(x + self_attention_output)

        encoder_attention_output = self.encoder_attention(norm1_output, encoder_output)
        encoder_attention_output = self.dropout2(encoder_attention_output, training=training)
        norm2_output = self.layer_norm2(norm1_output + encoder_attention_output)

        ff_output = self.feed_forward(norm2_output)
        ff_output = self.dropout3(ff_output, training=training)
        return self.layer_norm3(norm2_output + ff_output)

def create_transformer(input_vocab_size, output_vocab_size, max_input_len, max_output_len):
    embed_dim = 256
    num_heads = 4
    ff_dim = 512
    encoder_inputs = Input(shape=(max_input_len,))
    encoder_emb = Embedding(input_vocab_size, embed_dim)(encoder_inputs)
    encoder_pos_emb = PositionalEncodingLayer(max_input_len, embed_dim)(encoder_emb)
    encoder_output = TransformerDecoderLayer(embed_dim, num_heads, ff_dim)(encoder_pos_emb, encoder_pos_emb, training=True)  # Using one decoder block for simplicity
    encoder_output = LayerNormalization()(encoder_output)
    decoder_inputs = Input(shape=(max_output_len-1,))
    decoder_emb = Embedding(output_vocab_size, embed_dim)(decoder_inputs)
    decoder_pos_emb = PositionalEncodingLayer(max_output_len, embed_dim)(decoder_emb)
    decoder_output = TransformerDecoderLayer(embed_dim, num_heads, ff_dim)(decoder_pos_emb, encoder_output, training=True)
    decoder_output = LayerNormalization()(decoder_output)
    final_output = Dense(output_vocab_size, activation="softmax")(decoder_output)
    transformer_model = Model(inputs=[encoder_inputs, decoder_inputs], outputs=final_output)
    transformer_model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

    return transformer_model

# %%
model = create_transformer(input_vocab_size, output_vocab_size, max_input_len, max_output_len)

model.fit(
    [X_train, y_train[:, :-1]],
    y_train[:, 1:, np.newaxis],
    epochs=50,
    batch_size=64,
    validation_data=([X_val, y_val[:, :-1]], y_val[:, 1:, np.newaxis])
)
# Out:
# Epoch 1/50
# 345/345 [==============================] - 50s 135ms/step - loss: 1.7119 - accuracy: 0.7483 - val_loss: 1.3947 - val_accuracy: 0.7692
# Epoch 2/50
# 345/345 [==============================] - 46s 135ms/step - loss: 1.3244 - accuracy: 0.7766 - val_loss: 1.2814 - val_accuracy: 0.7830
# Epoch 3/50
# 345/345 [==============================] - 47s 136ms/step - loss: 1.1967 - accuracy: 0.7913 - val_loss: 1.1627 - val_accuracy: 0.8051
# Epoch 4/50
# 345/345 [==============================] - 47s 136ms/step - loss: 1.0705 - accuracy: 0.8108 - val_loss: 1.1006 - val_accuracy: 0.8127
# Epoch 5/50
# 345/345 [==============================] - 47s 137ms/step - loss: 0.9888 - accuracy: 0.8190 - val_loss: 1.0654 - val_accuracy: 0.8167
# Epoch 6/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.9313 - accuracy: 0.8249 - val_loss: 1.0466 - val_accuracy: 0.8193
# Epoch 7/50
# 345/345 [==============================] - 49s 143ms/step - loss: 0.8740 - accuracy: 0.8313 - val_loss: 1.0209 - val_accuracy: 0.8227
# Epoch 8/50
# 345/345 [==============================] - 49s 143ms/step - loss: 0.8233 - accuracy: 0.8369 - val_loss: 1.0069 - val_accuracy: 0.8276
# Epoch 9/50
# 345/345 [==============================] - 50s 144ms/step - loss: 0.7828 - accuracy: 0.8416 - val_loss: 1.0051 - val_accuracy: 0.8285
# Epoch 10/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.7439 - accuracy: 0.8465 - val_loss: 0.9867 - val_accuracy: 0.8327
# Epoch 11/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.7100 - accuracy: 0.8511 - val_loss: 0.9787 - val_accuracy: 0.8315
# Epoch 12/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.6784 - accuracy: 0.8554 - val_loss: 0.9763 - val_accuracy: 0.8363
# Epoch 13/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.6500 - accuracy: 0.8596 - val_loss: 0.9785 - val_accuracy: 0.8358
# Epoch 14/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.6247 - accuracy: 0.8624 - val_loss: 0.9775 - val_accuracy: 0.8375
# Epoch 15/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.5972 - accuracy: 0.8666 - val_loss: 0.9653 - val_accuracy: 0.8405
# Epoch 16/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.6139 - accuracy: 0.8626 - val_loss: 0.9664 - val_accuracy: 0.8416
# Epoch 17/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.5604 - accuracy: 0.8714 - val_loss: 0.9710 - val_accuracy: 0.8411
# Epoch 18/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.5293 - accuracy: 0.8768 - val_loss: 0.9595 - val_accuracy: 0.8442
# Epoch 19/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.5074 - accuracy: 0.8799 - val_loss: 0.9598 - val_accuracy: 0.8440
# Epoch 20/50
# 345/345 [==============================] - 49s 142ms/step - loss: 0.4844 - accuracy: 0.8837 - val_loss: 0.9622 - val_accuracy: 0.8450
# Epoch 21/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.4640 - accuracy: 0.8871 - val_loss: 0.9503 - val_accuracy: 0.8487
# Epoch 22/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.4440 - accuracy: 0.8899 - val_loss: 0.9611 - val_accuracy: 0.8482
# Epoch 23/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.4201 - accuracy: 0.8940 - val_loss: 0.9461 - val_accuracy: 0.8508
# Epoch 24/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.3987 - accuracy: 0.8974 - val_loss: 0.9436 - val_accuracy: 0.8528
# Epoch 25/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.3779 - accuracy: 0.9010 - val_loss: 0.9508 - val_accuracy: 0.8516
# Epoch 26/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.3641 - accuracy: 0.9038 - val_loss: 0.9426 - val_accuracy: 0.8555
# Epoch 27/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.3417 - accuracy: 0.9081 - val_loss: 0.9312 - val_accuracy: 0.8568
# Epoch 28/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.3226 - accuracy: 0.9119 - val_loss: 0.9364 - val_accuracy: 0.8578
# Epoch 29/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.3101 - accuracy: 0.9145 - val_loss: 0.9423 - val_accuracy: 0.8587
# Epoch 30/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.2926 - accuracy: 0.9183 - val_loss: 0.9395 - val_accuracy: 0.8602
# Epoch 31/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.2795 - accuracy: 0.9213 - val_loss: 0.9410 - val_accuracy: 0.8618
# Epoch 32/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.2652 - accuracy: 0.9246 - val_loss: 0.9399 - val_accuracy: 0.8631
# Epoch 33/50
# 345/345 [==============================] - 48s 139ms/step - loss: 0.2513 - accuracy: 0.9280 - val_loss: 0.9489 - val_accuracy: 0.8638
# Epoch 34/50
# 345/345 [==============================] - 49s 141ms/step - loss: 0.2369 - accuracy: 0.9313 - val_loss: 0.9534 - val_accuracy: 0.8650
# Epoch 35/50
# 345/345 [==============================] - 50s 146ms/step - loss: 0.2279 - accuracy: 0.9338 - val_loss: 0.9581 - val_accuracy: 0.8645
# Epoch 36/50
# 345/345 [==============================] - 48s 140ms/step - loss: 0.2198 - accuracy: 0.9355 - val_loss: 0.9733 - val_accuracy: 0.8649
# Epoch 37/50
# 345/345 [==============================] - 50s 145ms/step - loss: 0.2137 - accuracy: 0.9368 - val_loss: 0.9832 - val_accuracy: 0.8641
# Epoch 38/50
# 345/345 [==============================] - 51s 147ms/step - loss: 0.2029 - accuracy: 0.9399 - val_loss: 0.9627 - val_accuracy: 0.8677
# Epoch 39/50
# 345/345 [==============================] - 51s 148ms/step - loss: 0.1978 - accuracy: 0.9411 - val_loss: 0.9742 - val_accuracy: 0.8669
# Epoch 40/50
# 345/345 [==============================] - 54s 157ms/step - loss: 0.1847 - accuracy: 0.9444 - val_loss: 0.9700 - val_accuracy: 0.8708
# Epoch 41/50
# 345/345 [==============================] - 54s 156ms/step - loss: 0.1777 - accuracy: 0.9463 - val_loss: 0.9805 - val_accuracy: 0.8700
# Epoch 42/50
# 345/345 [==============================] - 54s 155ms/step - loss: 0.1741 - accuracy: 0.9471 - val_loss: 0.9742 - val_accuracy: 0.8707
# Epoch 43/50
# 345/345 [==============================] - 55s 158ms/step - loss: 0.1829 - accuracy: 0.9454 - val_loss: 0.9804 - val_accuracy: 0.8701
# Epoch 44/50
# 345/345 [==============================] - 53s 155ms/step - loss: 0.1632 - accuracy: 0.9501 - val_loss: 0.9820 - val_accuracy: 0.8730
# Epoch 45/50
# 345/345 [==============================] - 53s 152ms/step - loss: 0.1550 - accuracy: 0.9524 - val_loss: 0.9783 - val_accuracy: 0.8733
# Epoch 46/50
# 345/345 [==============================] - 53s 154ms/step - loss: 0.1542 - accuracy: 0.9526 - val_loss: 0.9927 - val_accuracy: 0.8743
# Epoch 47/50
# 345/345 [==============================] - 54s 156ms/step - loss: 0.1475 - accuracy: 0.9543 - val_loss: 0.9960 - val_accuracy: 0.8737
# Epoch 48/50
# 345/345 [==============================] - 53s 154ms/step - loss: 0.1451 - accuracy: 0.9551 - val_loss: 1.0051 - val_accuracy: 0.8747
# Epoch 49/50
# 345/345 [==============================] - 53s 154ms/step - loss: 0.1389 - accuracy: 0.9564 - val_loss: 1.0115 - val_accuracy: 0.8756
# Epoch 50/50
# 345/345 [==============================] - 53s 154ms/step - loss: 0.1429 - accuracy: 0.9555 - val_loss: 1.0100 - val_accuracy: 0.8765

# %%
english_sentences = df['english'].values
urdu_sentences = df['urdu'].values

transformer_bleu_score = evaluate_model_bleu(
    transformer_model,
    eng_tokenizer,
    urdu_tokenizer,
    english_sentences[:100],
    urdu_sentences[:100],
    max_input_len,
    max_output_len
)


trans_models['Transformer'] =transformer_bleu_score


print(trans_models['Transformer'])
# Out:
# 0.5158021472779767

# %%
blue_scores = pd.DataFrame(list(trans_models.items()), columns=['Model', 'BLEU Score'])
blue_scores['BLEU Score'] = blue_scores['BLEU Score'].map(lambda x: round(x, 4))
print(blue_scores.to_string(index=False))
# Out:
#       Model  BLEU Score
#   RNN_Model      0.0018
# BIRNN_Model      0.0538
#  LSTM_Model      0.0573
# Transformer      0.5158

# %%
#Load GloVe embeddings from a file
def load_glove_embeddings(filepath, embedding_dim=100):
    """Loads pre-trained GloVe embeddings from a file and returns them as a dictionary."""
    embeddings_index = {}
    with open(filepath, encoding='utf-8') as file:
        for line in file:
            values = line.strip().split()
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = vector
    return embeddings_index

#Generate the embedding matrix for the tokenizer's word index
def create_embedding_matrix(word_index, embeddings_index, embedding_dim=100):
    """Creates an embedding matrix using GloVe embeddings for each word in the word_index."""
    embedding_matrix = np.random.uniform(-0.05, 0.05, (len(word_index) + 1, embedding_dim))  # Random initialization
    for word, index in word_index.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[index] = embedding_vector  # Replace with the GloVe vector
    return embedding_matrix

# Build an RNN-based sequence-to-sequence model
def build_rnn_model(embedding_matrix=None, embedding_dim=100, max_input_len=50, max_output_len=50, input_vocab_size=None, output_vocab_size=None):
    """
    Builds an RNN model with the option to include pre-trained word embeddings.
    If embedding_matrix is provided, it will use that for the encoder.
    """
    # Encoder
    encoder_input = Input(shape=(max_input_len,))
    if embedding_matrix is not None:
        enc_emb = Embedding(input_dim=embedding_matrix.shape[0],
                            output_dim=embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_input_len,
                            trainable=False)(encoder_input)
    else:
        enc_emb = Embedding(input_vocab_size, embedding_dim)(encoder_input)

    encoder_output, state_h = SimpleRNN(256, return_state=True)(enc_emb)

    # Decoder
    decoder_input = Input(shape=(max_output_len - 1,))
    dec_emb = Embedding(output_vocab_size, 256)(decoder_input)
    decoder_output = SimpleRNN(256, return_sequences=True)(dec_emb, initial_state=state_h)

    # Output layer
    output = Dense(output_vocab_size, activation='softmax')(decoder_output)

    # Compile the model
    model = Model([encoder_input, decoder_input], output)
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=["accuracy"])

    return model

# %%
rnn_model_random = build_rnn_model()

rnn_model_random.fit(
    [X_train, y_train[:, :-1]],
    y_train[:, 1:, np.newaxis],
    epochs=50,
    batch_size=64,
    validation_data=([X_val, y_val[:, :-1]], y_val[:, 1:, np.newaxis])
)
# Out:
# Epoch 1/50
# 345/345 [==============================] - 18s 50ms/step - loss: 1.7410 - accuracy: 0.7499 - val_loss: 1.3645 - val_accuracy: 0.7756
# Epoch 2/50
# 345/345 [==============================] - 17s 50ms/step - loss: 1.2742 - accuracy: 0.7840 - val_loss: 1.2236 - val_accuracy: 0.7911
# Epoch 3/50
# 345/345 [==============================] - 18s 51ms/step - loss: 1.1400 - accuracy: 0.7981 - val_loss: 1.1545 - val_accuracy: 0.7984
# Epoch 4/50
# 345/345 [==============================] - 18s 51ms/step - loss: 1.0565 - accuracy: 0.8063 - val_loss: 1.1215 - val_accuracy: 0.8029
# Epoch 5/50
# 345/345 [==============================] - 18s 51ms/step - loss: 0.9965 - accuracy: 0.8118 - val_loss: 1.1052 - val_accuracy: 0.8044
# Epoch 6/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.9486 - accuracy: 0.8164 - val_loss: 1.0960 - val_accuracy: 0.8071
# Epoch 7/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.9084 - accuracy: 0.8208 - val_loss: 1.0924 - val_accuracy: 0.8081
# Epoch 8/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.8740 - accuracy: 0.8246 - val_loss: 1.0887 - val_accuracy: 0.8077
# Epoch 9/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.8433 - accuracy: 0.8286 - val_loss: 1.0930 - val_accuracy: 0.8092
# Epoch 10/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.8173 - accuracy: 0.8326 - val_loss: 1.0944 - val_accuracy: 0.8089
# Epoch 11/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.7935 - accuracy: 0.8365 - val_loss: 1.1001 - val_accuracy: 0.8093
# Epoch 12/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.7717 - accuracy: 0.8403 - val_loss: 1.1037 - val_accuracy: 0.8097
# Epoch 13/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.7528 - accuracy: 0.8434 - val_loss: 1.1116 - val_accuracy: 0.8097
# Epoch 14/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.7355 - accuracy: 0.8463 - val_loss: 1.1165 - val_accuracy: 0.8097
# Epoch 15/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.7203 - accuracy: 0.8491 - val_loss: 1.1233 - val_accuracy: 0.8093
# Epoch 16/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.7062 - accuracy: 0.8516 - val_loss: 1.1297 - val_accuracy: 0.8091
# Epoch 17/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.6933 - accuracy: 0.8543 - val_loss: 1.1382 - val_accuracy: 0.8091
# Epoch 18/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.6811 - accuracy: 0.8563 - val_loss: 1.1419 - val_accuracy: 0.8062
# Epoch 19/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.6705 - accuracy: 0.8583 - val_loss: 1.1509 - val_accuracy: 0.8099
# Epoch 20/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.6612 - accuracy: 0.8602 - val_loss: 1.1588 - val_accuracy: 0.8104
# Epoch 21/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6515 - accuracy: 0.8623 - val_loss: 1.1657 - val_accuracy: 0.8087
# Epoch 22/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6436 - accuracy: 0.8636 - val_loss: 1.1738 - val_accuracy: 0.8087
# Epoch 23/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6363 - accuracy: 0.8652 - val_loss: 1.1825 - val_accuracy: 0.8082
# Epoch 24/50
# 345/345 [==============================] - 18s 54ms/step - loss: 0.6294 - accuracy: 0.8666 - val_loss: 1.1891 - val_accuracy: 0.8084
# Epoch 25/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6231 - accuracy: 0.8674 - val_loss: 1.1950 - val_accuracy: 0.8081
# Epoch 26/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6176 - accuracy: 0.8680 - val_loss: 1.2035 - val_accuracy: 0.8085
# Epoch 27/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6121 - accuracy: 0.8695 - val_loss: 1.2091 - val_accuracy: 0.8083
# Epoch 28/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6077 - accuracy: 0.8700 - val_loss: 1.2154 - val_accuracy: 0.8085
# Epoch 29/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.6035 - accuracy: 0.8708 - val_loss: 1.2240 - val_accuracy: 0.8080
# Epoch 30/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5995 - accuracy: 0.8717 - val_loss: 1.2294 - val_accuracy: 0.8083
# Epoch 31/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5960 - accuracy: 0.8724 - val_loss: 1.2343 - val_accuracy: 0.8083
# Epoch 32/50
# 345/345 [==============================] - 18s 54ms/step - loss: 0.5925 - accuracy: 0.8728 - val_loss: 1.2414 - val_accuracy: 0.8072
# Epoch 33/50
# 345/345 [==============================] - 18s 54ms/step - loss: 0.5893 - accuracy: 0.8734 - val_loss: 1.2503 - val_accuracy: 0.8077
# Epoch 34/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5864 - accuracy: 0.8737 - val_loss: 1.2548 - val_accuracy: 0.8077
# Epoch 35/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5843 - accuracy: 0.8740 - val_loss: 1.2591 - val_accuracy: 0.8076
# Epoch 36/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5819 - accuracy: 0.8741 - val_loss: 1.2673 - val_accuracy: 0.8071
# Epoch 37/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5797 - accuracy: 0.8744 - val_loss: 1.2730 - val_accuracy: 0.8068
# Epoch 38/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5778 - accuracy: 0.8748 - val_loss: 1.2771 - val_accuracy: 0.8078
# Epoch 39/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5764 - accuracy: 0.8749 - val_loss: 1.2869 - val_accuracy: 0.8074
# Epoch 40/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5744 - accuracy: 0.8754 - val_loss: 1.2894 - val_accuracy: 0.8072
# Epoch 41/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5727 - accuracy: 0.8753 - val_loss: 1.2913 - val_accuracy: 0.8079
# Epoch 42/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5711 - accuracy: 0.8757 - val_loss: 1.2988 - val_accuracy: 0.8062
# Epoch 43/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5698 - accuracy: 0.8759 - val_loss: 1.3034 - val_accuracy: 0.8069
# Epoch 44/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5686 - accuracy: 0.8761 - val_loss: 1.3079 - val_accuracy: 0.8073
# Epoch 45/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5670 - accuracy: 0.8761 - val_loss: 1.3121 - val_accuracy: 0.8042
# Epoch 46/50
# 345/345 [==============================] - 18s 52ms/step - loss: 0.5666 - accuracy: 0.8759 - val_loss: 1.3176 - val_accuracy: 0.8079
# Epoch 47/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5651 - accuracy: 0.8760 - val_loss: 1.3216 - val_accuracy: 0.8070
# Epoch 48/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5643 - accuracy: 0.8763 - val_loss: 1.3230 - val_accuracy: 0.8071
# Epoch 49/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5634 - accuracy: 0.8765 - val_loss: 1.3265 - val_accuracy: 0.8073
# Epoch 50/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.5623 - accuracy: 0.8766 - val_loss: 1.3330 - val_accuracy: 0.8066

# %%
RNN_models = {}

# %%
RNN_models['RNN_Random'] =evaluate_bleu(rnn_model_random)

print("RNN Random Model Blue Score: ",RNN_models['RNN_Random'])
# Out:
# RNN Random Model Blue Score:  0.0015748820939085696

# %%
glove_path = '/content/glove.6B.100d.txt'
embedding_dim = 100
glove_index = load_glove_embeddings(glove_path, embedding_dim)
embedding_matrix = create_embedding_matrix(eng_tokenizer.word_index, glove_index, embedding_dim)

rnn_model_glove = build_rnn_model(embedding_matrix, embedding_dim)
rnn_model_glove.fit([X_train, y_train[:, :-1]], y_train[:, 1:, np.newaxis],
                    epochs=50, batch_size=64,
                    validation_data=([X_val, y_val[:, :-1]], y_val[:, 1:, np.newaxis]))
# Out:
# Epoch 1/50
# 345/345 [==============================] - 19s 52ms/step - loss: 1.7575 - accuracy: 0.7493 - val_loss: 1.3915 - val_accuracy: 0.7730
# Epoch 2/50
# 345/345 [==============================] - 17s 50ms/step - loss: 1.3045 - accuracy: 0.7812 - val_loss: 1.2623 - val_accuracy: 0.7867
# Epoch 3/50
# 345/345 [==============================] - 18s 51ms/step - loss: 1.1828 - accuracy: 0.7933 - val_loss: 1.1866 - val_accuracy: 0.7960
# Epoch 4/50
# 345/345 [==============================] - 18s 52ms/step - loss: 1.0910 - accuracy: 0.8029 - val_loss: 1.1385 - val_accuracy: 0.8010
# Epoch 5/50
# 345/345 [==============================] - 18s 52ms/step - loss: 1.0248 - accuracy: 0.8091 - val_loss: 1.1133 - val_accuracy: 0.7993
# Epoch 6/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.9732 - accuracy: 0.8138 - val_loss: 1.0990 - val_accuracy: 0.8061
# Epoch 7/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.9300 - accuracy: 0.8185 - val_loss: 1.0926 - val_accuracy: 0.8068
# Epoch 8/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.8932 - accuracy: 0.8229 - val_loss: 1.0890 - val_accuracy: 0.8079
# Epoch 9/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.8611 - accuracy: 0.8265 - val_loss: 1.0925 - val_accuracy: 0.8080
# Epoch 10/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.8321 - accuracy: 0.8308 - val_loss: 1.0904 - val_accuracy: 0.8090
# Epoch 11/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.8067 - accuracy: 0.8348 - val_loss: 1.0954 - val_accuracy: 0.8086
# Epoch 12/50
# 345/345 [==============================] - 18s 53ms/step - loss: 0.7840 - accuracy: 0.8385 - val_loss: 1.1026 - val_accuracy: 0.8086
# Epoch 13/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.7638 - accuracy: 0.8418 - val_loss: 1.1069 - val_accuracy: 0.8086
# Epoch 14/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.7452 - accuracy: 0.8449 - val_loss: 1.1127 - val_accuracy: 0.8090
# Epoch 15/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.7290 - accuracy: 0.8476 - val_loss: 1.1167 - val_accuracy: 0.8095
# Epoch 16/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.7142 - accuracy: 0.8501 - val_loss: 1.1228 - val_accuracy: 0.8090
# Epoch 17/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.7007 - accuracy: 0.8531 - val_loss: 1.1311 - val_accuracy: 0.8094
# Epoch 18/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6881 - accuracy: 0.8552 - val_loss: 1.1392 - val_accuracy: 0.8091
# Epoch 19/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6770 - accuracy: 0.8573 - val_loss: 1.1456 - val_accuracy: 0.8090
# Epoch 20/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6669 - accuracy: 0.8595 - val_loss: 1.1531 - val_accuracy: 0.8088
# Epoch 21/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6571 - accuracy: 0.8611 - val_loss: 1.1605 - val_accuracy: 0.8087
# Epoch 22/50
# 345/345 [==============================] - 20s 58ms/step - loss: 0.6491 - accuracy: 0.8624 - val_loss: 1.1685 - val_accuracy: 0.8089
# Epoch 23/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.6411 - accuracy: 0.8640 - val_loss: 1.1748 - val_accuracy: 0.8083
# Epoch 24/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.6342 - accuracy: 0.8653 - val_loss: 1.1835 - val_accuracy: 0.8081
# Epoch 25/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6276 - accuracy: 0.8665 - val_loss: 1.1906 - val_accuracy: 0.8089
# Epoch 26/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6218 - accuracy: 0.8675 - val_loss: 1.1992 - val_accuracy: 0.8086
# Epoch 27/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6161 - accuracy: 0.8689 - val_loss: 1.2064 - val_accuracy: 0.8079
# Epoch 28/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6113 - accuracy: 0.8694 - val_loss: 1.2103 - val_accuracy: 0.8087
# Epoch 29/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6063 - accuracy: 0.8705 - val_loss: 1.2196 - val_accuracy: 0.8080
# Epoch 30/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.6019 - accuracy: 0.8714 - val_loss: 1.2266 - val_accuracy: 0.8076
# Epoch 31/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5985 - accuracy: 0.8719 - val_loss: 1.2345 - val_accuracy: 0.8070
# Epoch 32/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5955 - accuracy: 0.8720 - val_loss: 1.2387 - val_accuracy: 0.8073
# Epoch 33/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5921 - accuracy: 0.8728 - val_loss: 1.2468 - val_accuracy: 0.8078
# Epoch 34/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5889 - accuracy: 0.8732 - val_loss: 1.2542 - val_accuracy: 0.8036
# Epoch 35/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5861 - accuracy: 0.8737 - val_loss: 1.2593 - val_accuracy: 0.8041
# Epoch 36/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5836 - accuracy: 0.8739 - val_loss: 1.2637 - val_accuracy: 0.8038
# Epoch 37/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5817 - accuracy: 0.8745 - val_loss: 1.2674 - val_accuracy: 0.8075
# Epoch 38/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5794 - accuracy: 0.8746 - val_loss: 1.2766 - val_accuracy: 0.8062
# Epoch 39/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5777 - accuracy: 0.8748 - val_loss: 1.2814 - val_accuracy: 0.8067
# Epoch 40/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5759 - accuracy: 0.8749 - val_loss: 1.2893 - val_accuracy: 0.8040
# Epoch 41/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5741 - accuracy: 0.8751 - val_loss: 1.2923 - val_accuracy: 0.8071
# Epoch 42/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5722 - accuracy: 0.8756 - val_loss: 1.2982 - val_accuracy: 0.8074
# Epoch 43/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5712 - accuracy: 0.8756 - val_loss: 1.3001 - val_accuracy: 0.8065
# Epoch 44/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5699 - accuracy: 0.8755 - val_loss: 1.3067 - val_accuracy: 0.8037
# Epoch 45/50
# 345/345 [==============================] - 19s 56ms/step - loss: 0.5687 - accuracy: 0.8754 - val_loss: 1.3132 - val_accuracy: 0.8072
# Epoch 46/50
# 345/345 [==============================] - 19s 54ms/step - loss: 0.5672 - accuracy: 0.8759 - val_loss: 1.3169 - val_accuracy: 0.8058
# Epoch 47/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5664 - accuracy: 0.8760 - val_loss: 1.3228 - val_accuracy: 0.8062
# Epoch 48/50
# 345/345 [==============================] - 19s 55ms/step - loss: 0.5653 - accuracy: 0.8760 - val_loss: 1.3280 - val_accuracy: 0.8061
# Epoch 49/50
# 345/345 [==============================] - 19s 56ms/step - loss: 0.5642 - accuracy: 0.8764 - val_loss: 1.3328 - val_accuracy: 0.8066
# Epoch 50/50
# 345/345 [==============================] - 19s 56ms/step - loss: 0.5634 - accuracy: 0.8763 - val_loss: 1.3356 - val_accuracy: 0.8074

# %%
RNN_models['RNN_Glove'] = evaluate_bleu(rnn_model_glove)

print("RNN Glove Model Blue Score: ",RNN_models['RNN_Glove'])
# Out:
# RNN Glove Model Blue Score:  0.0018692093576922583

# %%
rnn_blue_scores = pd.DataFrame(list(RNN_models.items()), columns=['Model', 'BLEU Score'])
rnn_blue_scores['BLEU Score'] = rnn_blue_scores['BLEU Score'].map(lambda x: round(x, 4))
print(rnn_blue_scores.to_string(index=False))
# Out:
#      Model  BLEU Score
# RNN_Random      0.0016
#  RNN_Glove      0.0019
